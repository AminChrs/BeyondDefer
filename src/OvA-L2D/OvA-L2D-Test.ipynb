# %%
import torch

# %%
model = torch.load('OvA-L2D/models/ova/default.pt', map_location=torch.device("cpu"))

# %%
model
# Out:
# OrderedDict([('conv1.weight',
#               tensor([[[[ 2.6404e-02, -5.8676e-02, -4.7135e-02],
#                         [-5.5089e-02,  8.3435e-02,  1.4029e-02],
#                         [-1.8351e-01, -5.8498e-02, -1.5729e-01]],
#
#                        [[-4.7569e-02, -1.7370e-01, -2.2357e-01],
#                         [ 2.1544e-01,  2.2984e-01,  2.2948e-02],
#                         [ 8.2693e-03,  1.3348e-01, -1.2843e-02]],
#
#                        [[-1.1714e-01, -2.8688e-02, -2.1284e-01],
#                         [ 2.0849e-01,  3.4993e-01,  9.5762e-02],
#                         [ 9.6601e-02,  2.4981e-01,  6.1262e-02]]],
#
#
#                       [[[-3.2993e-01, -3.3621e-01, -2.8907e-01],
#                         [-3.6980e-01, -4.8805e-01, -3.9593e-01],
#                         [-3.7766e-01, -3.4209e-01, -3.2289e-01]],
#
#                        [[-8.9227e-02, -3.2405e-02, -1.1002e-01],
#                         [-1.2277e-01, -1.4644e-01, -1.2454e-01],
# ...
